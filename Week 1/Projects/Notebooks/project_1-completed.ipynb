# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# The data describes the average SAT Math and Verbal scores of students across the U.S. along with the participation rate within each state in the U.S.

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# The result would have been more comprehensive if we had the actual scores of the students in each state. The average score might not be a good representation of the the score distributions in each state.

# %% [markdown]
# ##### 3. Create a data dictionary for the dataset.

# %% [markdown]
# dictionary = {"key": (values)}

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 4. Load the data into a list of lists

# %%
# !pwd
# Out:
# /Users/Lola/Documents/Dami_repo/Week 1/Projects/Notebooks

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
# %matplotlib inline
path ="../assets/sat_scores.csv"

import csv

def read_file(path):
    with open(path, 'r') as f:
        data = [row for row in csv.reader(f.read().splitlines())]
    return data

data = read_file(path)
print data
print path
# Out:
# [['State', 'Rate', 'Verbal', 'Math'], ['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547', '545'], ['MI', '11', '561', '572'], ['MN', '9', '580', '589'], ['KS', '9', '577', '580'], ['AL', '9', '559', '554'], ['NE', '8', '562', '568'], ['OK', '8', '567', '561'], ['MO', '8', '577', '577'], ['LA', '7', '564', '562'], ['WI', '6', '584', '596'], ['AR', '6', '562', '550'], ['UT', '5', '575', '570'], ['IA', '5', '593', '603'], ['SD', '4', '577', '582'], ['ND', '4', '592', '599'], ['MS', '4', '566', '551'], ['All', '45', '506', '514']]
# ../assets/sat_scores.csv

# %% [markdown]
# ##### 5. Print the data

# %%
print data
# Out:
# [['State', 'Rate', 'Verbal', 'Math'], ['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547', '545'], ['MI', '11', '561', '572'], ['MN', '9', '580', '589'], ['KS', '9', '577', '580'], ['AL', '9', '559', '554'], ['NE', '8', '562', '568'], ['OK', '8', '567', '561'], ['MO', '8', '577', '577'], ['LA', '7', '564', '562'], ['WI', '6', '584', '596'], ['AR', '6', '562', '550'], ['UT', '5', '575', '570'], ['IA', '5', '593', '603'], ['SD', '4', '577', '582'], ['ND', '4', '592', '599'], ['MS', '4', '566', '551'], ['All', '45', '506', '514']]

# %% [markdown]
# ##### 6. Extract a list of the labels from the data, and remove them from the data.

# %%
labels = data[0]
print labels
data = data[1:]
print data
# Out:
# ['State', 'Rate', 'Verbal', 'Math']
# [['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547', '545'], ['MI', '11', '561', '572'], ['MN', '9', '580', '589'], ['KS', '9', '577', '580'], ['AL', '9', '559', '554'], ['NE', '8', '562', '568'], ['OK', '8', '567', '561'], ['MO', '8', '577', '577'], ['LA', '7', '564', '562'], ['WI', '6', '584', '596'], ['AR', '6', '562', '550'], ['UT', '5', '575', '570'], ['IA', '5', '593', '603'], ['SD', '4', '577', '582'], ['ND', '4', '592', '599'], ['MS', '4', '566', '551'], ['All', '45', '506', '514']]

# %% [markdown]
# ##### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
def stateSelector(data): return data[0]
stateName = map(stateSelector, data)
print stateName
# Out:
# ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS', 'All']

# %% [markdown]
# ##### 8. Print the types of each column

# %%
for i in data[0]:
    print type(i)
# Out:
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>

# %% [markdown]
# ##### 9. Do any types need to be reassigned? If so, go ahead and do it. No

# %%
def get_correct_type(x): 
    sat = [x[0], int(x[1]), int(x[2]), int(x[3])]
    return sat
refinedData = map(get_correct_type, data)
print refinedData
# Out:
# [['CT', 82, 509, 510], ['NJ', 81, 499, 513], ['MA', 79, 511, 515], ['NY', 77, 495, 505], ['NH', 72, 520, 516], ['RI', 71, 501, 499], ['PA', 71, 500, 499], ['VT', 69, 511, 506], ['ME', 69, 506, 500], ['VA', 68, 510, 501], ['DE', 67, 501, 499], ['MD', 65, 508, 510], ['NC', 65, 493, 499], ['GA', 63, 491, 489], ['IN', 60, 499, 501], ['SC', 57, 486, 488], ['DC', 56, 482, 474], ['OR', 55, 526, 526], ['FL', 54, 498, 499], ['WA', 53, 527, 527], ['TX', 53, 493, 499], ['HI', 52, 485, 515], ['AK', 51, 514, 510], ['CA', 51, 498, 517], ['AZ', 34, 523, 525], ['NV', 33, 509, 515], ['CO', 31, 539, 542], ['OH', 26, 534, 439], ['MT', 23, 539, 539], ['WV', 18, 527, 512], ['ID', 17, 543, 542], ['TN', 13, 562, 553], ['NM', 13, 551, 542], ['IL', 12, 576, 589], ['KY', 12, 550, 550], ['WY', 11, 547, 545], ['MI', 11, 561, 572], ['MN', 9, 580, 589], ['KS', 9, 577, 580], ['AL', 9, 559, 554], ['NE', 8, 562, 568], ['OK', 8, 567, 561], ['MO', 8, 577, 577], ['LA', 7, 564, 562], ['WI', 6, 584, 596], ['AR', 6, 562, 550], ['UT', 5, 575, 570], ['IA', 5, 593, 603], ['SD', 4, 577, 582], ['ND', 4, 592, 599], ['MS', 4, 566, 551], ['All', 45, 506, 514]]

# %% [markdown]
# ##### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
def function(i):return (i[0], i[1:])
state_dict = map(function, refinedData)
myNewDict = dict(state_dict)
print myNewDict
# Out:
# {'WA': [53, 527, 527], 'DE': [67, 501, 499], 'DC': [56, 482, 474], 'WI': [6, 584, 596], 'WV': [18, 527, 512], 'HI': [52, 485, 515], 'FL': [54, 498, 499], 'WY': [11, 547, 545], 'NH': [72, 520, 516], 'NJ': [81, 499, 513], 'NM': [13, 551, 542], 'TX': [53, 493, 499], 'LA': [7, 564, 562], 'NC': [65, 493, 499], 'ND': [4, 592, 599], 'NE': [8, 562, 568], 'TN': [13, 562, 553], 'NY': [77, 495, 505], 'PA': [71, 500, 499], 'RI': [71, 501, 499], 'NV': [33, 509, 515], 'VA': [68, 510, 501], 'CO': [31, 539, 542], 'AK': [51, 514, 510], 'AL': [9, 559, 554], 'AR': [6, 562, 550], 'VT': [69, 511, 506], 'IL': [12, 576, 589], 'GA': [63, 491, 489], 'IN': [60, 499, 501], 'IA': [5, 593, 603], 'OK': [8, 567, 561], 'AZ': [34, 523, 525], 'CA': [51, 498, 517], 'ID': [17, 543, 542], 'CT': [82, 509, 510], 'ME': [69, 506, 500], 'MD': [65, 508, 510], 'All': [45, 506, 514], 'MA': [79, 511, 515], 'OH': [26, 534, 439], 'UT': [5, 575, 570], 'MO': [8, 577, 577], 'MN': [9, 580, 589], 'MI': [11, 561, 572], 'KS': [9, 577, 580], 'MT': [23, 539, 539], 'MS': [4, 566, 551], 'SC': [57, 486, 488], 'KY': [12, 550, 550], 'OR': [55, 526, 526], 'SD': [4, 577, 582]}

# %% [markdown]
# ##### 11. Create a dictionary with the values for each of the numeric columns

# %%
def get_dict(obj,i): return obj[i]
    
finalDict = []
for i in range (0,4):
    d = map(lambda obj: get_dict(obj,i), refinedData)
    finalDict.append(d)
finalDict
myDict = {"states" : finalDict[0], "rate": finalDict[1], "verbal": finalDict[2], "math": finalDict[3]}
print myDict
# Out:
# {'states': ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS', 'All'], 'rate': [82, 81, 79, 77, 72, 71, 71, 69, 69, 68, 67, 65, 65, 63, 60, 57, 56, 55, 54, 53, 53, 52, 51, 51, 34, 33, 31, 26, 23, 18, 17, 13, 13, 12, 12, 11, 11, 9, 9, 9, 8, 8, 8, 7, 6, 6, 5, 5, 4, 4, 4, 45], 'math': [510, 513, 515, 505, 516, 499, 499, 506, 500, 501, 499, 510, 499, 489, 501, 488, 474, 526, 499, 527, 499, 515, 510, 517, 525, 515, 542, 439, 539, 512, 542, 553, 542, 589, 550, 545, 572, 589, 580, 554, 568, 561, 577, 562, 596, 550, 570, 603, 582, 599, 551, 514], 'verbal': [509, 499, 511, 495, 520, 501, 500, 511, 506, 510, 501, 508, 493, 491, 499, 486, 482, 526, 498, 527, 493, 485, 514, 498, 523, 509, 539, 534, 539, 527, 543, 562, 551, 576, 550, 547, 561, 580, 577, 559, 562, 567, 577, 564, 584, 562, 575, 593, 577, 592, 566, 506]}

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 12. Print the min and max of each column

# %%
def minMax():
    for key, value in myDict.items():
        print "Key: " + key
        print "Max: " + str(max(value))
        print "Min: " + str(min(value))
minMax()
# Out:
# Key: states
# Max: WY
# Min: AK
# Key: rate
# Max: 82
# Min: 4
# Key: math
# Max: 603
# Min: 439
# Key: verbal
# Max: 593
# Min: 482

# %% [markdown]
# ##### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
db = pd.read_csv(path)
np.std(db.Math)
# Out:
# 35.66699616430595

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


#print db.dtypes

#db.columns = ["state", "rate", "verbal", "math"]
plt.hist(db.Rate, bins = 20)
plt.title("Distribution of Participation Rate", size = 14)
plt.xlabel("Rate")
plt.ylabel("Frequency")
plt.show
plt.close
# Out:
# <function matplotlib.pyplot.close>

# %% [markdown]
# ##### 15. Plot the Math distribution

# %%
plt.hist(db.Math, bins = 20)
plt.title("Distribution of Math Scores", size = 14)
plt.xlabel("Math")
plt.ylabel("Frequency")
plt.show
plt.close
# Out:
# <function matplotlib.pyplot.close>

# %% [markdown]
# ##### 16. Plot the Verbal distribution

# %%
plt.hist(db.Verbal, bins = 20)
plt.title("Distribution of Verbal Scores", size = 14)
plt.xlabel("Verbal")
plt.ylabel("Frequency")
plt.show
plt.close
# Out:
# <function matplotlib.pyplot.close>

# %% [markdown]
# ##### 17. What is the typical assumption for data distribution?

# %% [markdown]
# A data distribution is typically assumed to be normally distributed.

# %% [markdown]
# ##### 18. Does that distribution hold true for our data?

# %% [markdown]
# The Math distribution appears to be the closest to a normal distribution.

# %% [markdown]
# ##### 19. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
plt.scatter(db.Verbal, db.Math, c='b')
plt.title("Verbal and Math", size = 14)
plt.xlabel("Verbal")
plt.ylabel("Math")
plt.show
plt.close
# Out:
# <function matplotlib.pyplot.close>

# %%
plt.scatter(db.Verbal, db.Rate, c='darkred')
plt.title("Verbal and Participation Rate", size = 14)
plt.xlabel("Verbal")
plt.ylabel("Rate")
plt.show
plt.close
# Out:
# <function matplotlib.pyplot.close>

# %%
plt.scatter(db.Math, db.Rate, c='g')
plt.title("Math and Participation Rate", size = 14)
plt.xlabel("Math")
plt.ylabel("Rate")
plt.show
plt.close
# Out:
# <function matplotlib.pyplot.close>

# %% [markdown]
# ##### 20. Are there any interesting relationships to note?

# %% [markdown]
# There appears to be a positive correlation between Math scores and Verbal scores i.e states with high Verbal scores were likely to also have high Math scores, and vice versa. There is a negative correlation between Verbal scores and participation rate i.e. states with higher Verbal scores were likely to have lower participation rates. The same result applies to Math scores.

# %% [markdown]
# ##### 21. Create box plots for each variable.

# %%
plt.boxplot(db.Rate)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1195d0b50>],
#  'caps': [<matplotlib.lines.Line2D at 0x1195d9450>,
#   <matplotlib.lines.Line2D at 0x1195d9790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1195ea210>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1195d9950>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1195d0510>,
#   <matplotlib.lines.Line2D at 0x1195d05d0>]}

# %%
plt.boxplot(db.Verbal)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1195140d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x119389610>,
#   <matplotlib.lines.Line2D at 0x11943a810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11943a510>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11943a310>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x119443ad0>,
#   <matplotlib.lines.Line2D at 0x119389290>]}

# %%
plt.boxplot(db.Math)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1195e1a50>],
#  'caps': [<matplotlib.lines.Line2D at 0x118a69510>,
#   <matplotlib.lines.Line2D at 0x118a69210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1165f9190>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x104112fd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x118a9c110>,
#   <matplotlib.lines.Line2D at 0x118a9cb50>]}

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %%
from IPython.display import Image
Image(filename='../assets/Verbal.png')

# %%
Image(filename='../assets/Math.png')

# %%
Image(filename='../assets/Rate.png')

# %%
Image(filename='../assets/Verbal_Participation.png')

# %%
Image(filename='../assets/Math_Participation.png')
