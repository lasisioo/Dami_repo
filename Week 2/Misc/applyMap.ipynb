# %%
import pandas as pd
df = pd.DataFrame({"a":[1,2,3], "b":[4,5,6], "c":[7,8,9]})
func1 = lambda x: x*2
func2 = lambda x: x.max() - x.min()
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df2 =df.b.map(func1)
df2
# Out:
# 0     8
# 1    10
# 2    12
# Name: b, dtype: int64

# %%
df3 = df.applymap(func1)
df3
# Out:
#    a   b   c
# 0  2   8  14
# 1  4  10  16
# 2  6  12  18

# %%
df4 = df.apply(func2)
df4
# Out:
# a    2
# b    2
# c    2
# dtype: int64
